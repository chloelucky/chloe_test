# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain.prompts.few_shot import FewShotPromptTemplate
from langchain.callbacks import StreamingStdOutCallbackHandler
from langchain.prompts.example_selector import LengthBasedExampleSelector

chat = ChatOpenAI(
    model_name='gpt-4o-mini-2024-07-18', 
    temperature=0.1, 
    streaming=True, 
    callbacks=[StreamingStdOutCallbackHandler()
    ]
)

examples = [
    {
        "country": "France",
        "answer": """
        Here is what I know:"
        Capital: Paris"
        Language: French"
        Food: Wine and Cheese"
        Currency: Euro"
        """,
    },
    {
        "country": "Italy",
        "answer": """
        I know this:
        Capital: Rome
        Language: Italian
        Food: Pizza and Pasta
        Currency: Euro
        """,
    },
    {
        "country": "Greece",
        "answer": """
        I know this:"
        Capital: Athens"
        Language: Greek"
        Food: Souvlaki and Feta Cheese"
        Currency: Euro"
        """,
    },
]

example_prompt = PromptTemplate.from_template("Human: {question}\nAI:{answer}")

example_selector = LengthBasedExampleSelector(
    examples=examples,
    example_prompt=example_prompt,
    max_length=10
)

prompt = FewShotPromptTemplate(
    example_prompt=example_prompt,
    example_selector=example_selector,
    suffix="Human: What do you know about {country}?",
    input_variables=["country"],
)

prompt.format(country="Brazil")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 50
#      15 examples = [
#      16     {
#      17         "country": "France",
#    (...)
#      45     },
#      46 ]
#      48 example_prompt = PromptTemplate.from_template("Human: {question}\nAI:{answer}")
# ---> 50 example_selector = LengthBasedExampleSelector(
#      51     examples=examples,
#      52     example_prompt=example_prompt,
#      53     max_length=10
#      54 )
#      56 prompt = FewShotPromptTemplate(
#      57     example_prompt=example_prompt,
#      58     example_selector=example_selector,
#      59     suffix="Human: What do you know about {country}?",
#      60     input_variables=["country"],
#      61 )
#      63 prompt.format(country="Brazil")
#
# File ~/.pyenv/versions/3.11.6/envs/gpt-env/lib/python3.11/site-packages/pydantic/main.py:339, in pydantic.main.BaseModel.__init__()
#
# File ~/.pyenv/versions/3.11.6/envs/gpt-env/lib/python3.11/site-packages/pydantic/main.py:1076, in pydantic.main.validate_model()
#
# File ~/.pyenv/versions/3.11.6/envs/gpt-env/lib/python3.11/site-packages/pydantic/fields.py:898, in pydantic.fields.ModelField.validate()
#
# File ~/.pyenv/versions/3.11.6/envs/gpt-env/lib/python3.11/site-packages/pydantic/fields.py:1157, in pydantic.fields.ModelField._apply_validators()
#
# File ~/.pyenv/versions/3.11.6/envs/gpt-env/lib/python3.11/site-packages/pydantic/class_validators.py:306, in pydantic.class_validators._generic_validator_cls.lambda5()
#
# File ~/.pyenv/versions/3.11.6/envs/gpt-env/lib/python3.11/site-packages/langchain/prompts/example_selector/length_based.py:46, in LengthBasedExampleSelector.calculate_example_text_lengths(cls, v, values)
#      44 example_prompt = values["example_prompt"]
#      45 get_text_length = values["get_text_length"]
# ---> 46 string_examples = [example_prompt.format(**eg) for eg in values["examples"]]
#      47 return [get_text_length(eg) for eg in string_examples]
#
# File ~/.pyenv/versions/3.11.6/envs/gpt-env/lib/python3.11/site-packages/langchain/prompts/example_selector/length_based.py:46, in <listcomp>(.0)
#      44 example_prompt = values["example_prompt"]
#      45 get_text_length = values["get_text_length"]
# ---> 46 string_examples = [example_prompt.format(**eg) for eg in values["examples"]]
#      47 return [get_text_length(eg) for eg in string_examples]
#
# File ~/.pyenv/versions/3.11.6/envs/gpt-env/lib/python3.11/site-packages/langchain/prompts/prompt.py:126, in PromptTemplate.format(self, **kwargs)
#     111 """Format the prompt with the inputs.
#     112
#     113 Args:
#    (...)
#     123         prompt.format(variable1="foo")
#     124 """
#     125 kwargs = self._merge_partial_and_user_variables(**kwargs)
# --> 126 return DEFAULT_FORMATTER_MAPPING[self.template_format](self.template, **kwargs)
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/string.py:190, in Formatter.format(self, format_string, *args, **kwargs)
#     189 def format(self, format_string, /, *args, **kwargs):
# --> 190     return self.vformat(format_string, args, kwargs)
#
# File ~/.pyenv/versions/3.11.6/envs/gpt-env/lib/python3.11/site-packages/langchain/utils/formatting.py:29, in StrictFormatter.vformat(self, format_string, args, kwargs)
#      24 if len(args) > 0:
#      25     raise ValueError(
#      26         "No arguments should be provided, "
#      27         "everything should be passed as keyword arguments."
#      28     )
# ---> 29 return super().vformat(format_string, args, kwargs)
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/string.py:194, in Formatter.vformat(self, format_string, args, kwargs)
#     192 def vformat(self, format_string, args, kwargs):
#     193     used_args = set()
# --> 194     result, _ = self._vformat(format_string, args, kwargs, used_args, 2)
#     195     self.check_unused_args(used_args, args, kwargs)
#     196     return result
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/string.py:234, in Formatter._vformat(self, format_string, args, kwargs, used_args, recursion_depth, auto_arg_index)
#     230     auto_arg_index = False
#     232 # given the field_name, find the object it references
#     233 #  and the argument it came from
# --> 234 obj, arg_used = self.get_field(field_name, args, kwargs)
#     235 used_args.add(arg_used)
#     237 # do any conversion on the resulting object
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/string.py:299, in Formatter.get_field(self, field_name, args, kwargs)
#     296 def get_field(self, field_name, args, kwargs):
#     297     first, rest = _string.formatter_field_name_split(field_name)
# --> 299     obj = self.get_value(first, args, kwargs)
#     301     # loop through the rest of the field_name, doing
#     302     #  getattr or getitem as needed
#     303     for is_attr, i in rest:
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/string.py:256, in Formatter.get_value(self, key, args, kwargs)
#     254     return args[key]
#     255 else:
# --> 256     return kwargs[key]
#
# KeyError: 'question'
